# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mne

# %%
path_raw_EEG = os.getcwd() + '/EEG'
path_raw_EEG

# Pick a participant
participant = 1

participant_vhdr = os.listdir(path_raw_EEG)[3*participant-2]
participant_vhdr
# Out:
# 'suj11_l2nap_day2.vhdr'

# %%
raw = mne.io.read_raw_brainvision(path_raw_EEG + '/' + participant_vhdr, preload=True)
# Out:
# Extracting parameters from c:\Users\khngu\Documents\cogs118a-project-main/EEG/suj11_l2nap_day2.vhdr...
# Setting channel info structure...
# Reading 0 ... 1806049  =      0.000 ...  1806.049 secs...

# %%
raw.plot(start=1000);
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
raw.plot(start=1000, highpass=1);
# Out:
# Setting up high-pass filter at 1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 1.00 Hz: -6.02 dB
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
# raw.plot(start=1455, highpass=1, lowpass=50);
raw.plot(start=1000, highpass=1, lowpass=30);
# Out:
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
# raw.plot(start=1455, highpass=11, lowpass=16);
raw.plot(start=1000, highpass=11, lowpass=16);
# Out:
# Setting up band-pass filter from 11 - 16 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 11.00, 16.00 Hz: -6.02, -6.02 dB
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
raw.plot(start=1660, highpass=1, lowpass=10);
# Out:
# Setting up band-pass filter from 1 - 10 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 10.00 Hz: -6.02, -6.02 dB
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
kcomplex = raw.filter(1, 10)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 2.50 Hz (-6 dB cutoff frequency: 11.25 Hz)
# - Filter length: 3301 samples (3.301 sec)

# %%
data_kcomplex = kcomplex.get_data(start=1660, stop=1670)
data_kcomplex.shape
# Out:
# (64, 10)

# %%
data_kcomplex
# Out:
# array([[-3.17288400e-06, -3.09571740e-06, -3.01999733e-06,
#         -2.94588108e-06, -2.87371456e-06, -2.80396972e-06,
#         -2.73714707e-06, -2.67339469e-06, -2.61309631e-06,
#         -2.55653634e-06],
#        [ 5.95316202e-07,  6.19696417e-07,  6.41280014e-07,
#          6.60027488e-07,  6.75752031e-07,  6.88224972e-07,
#          6.97166172e-07,  7.02470181e-07,  7.03932380e-07,
#          7.01430414e-07],
#        [ 1.15704587e-06,  1.19361186e-06,  1.22725703e-06,
#          1.25802196e-06,  1.28568493e-06,  1.31009229e-06,
#          1.33092892e-06,  1.34809377e-06,  1.36142770e-06,
#          1.37083936e-06],
#        [ 9.68550658e-07,  9.85565969e-07,  1.00035994e-06,
#          1.01293581e-06,  1.02329774e-06,  1.03124623e-06,
#          1.03665551e-06,  1.03952821e-06,  1.03976650e-06,
#          1.03730928e-06],
#        [ 3.46384882e-07,  3.57533414e-07,  3.68038129e-07,
#          3.78059072e-07,  3.87517439e-07,  3.96243279e-07,
# ...
